# %% [markdown]
# <a href="https://colab.research.google.com/github/EricVPereira/Inteligencia-Artificial-Trabalho/blob/main/Entrega_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrega I

# %%
import pandas as pd #Importa a biblioteca Pandas

# %%
# !wget 'https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2012.csv' #Importa os arquivos utilizados
# !wget 'https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2013.csv'
# !wget 'https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2014.csv'
# !wget 'https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2015.csv'
# !wget 'https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2016.csv'
# Out:
# --2022-08-28 23:06:11--  https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2012.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=reclamacoes-fundamentadas-sindec-2012.csv’
#
# data?select=reclama     [ <=>                ]  19.60K   102KB/s    in 0.2s
#
# 2022-08-28 23:06:12 (102 KB/s) - ‘data?select=reclamacoes-fundamentadas-sindec-2012.csv’ saved [20069]
#
# --2022-08-28 23:06:12--  https://www.kaggle.com/code/thiagobg/procon-dataset-overview/data?select=reclamacoes-fundamentadas-sindec-2013.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Datasets/reclamacoes-fundamentadas-sindec-2012.csv', nrows=1000) #Le o arquivo reclamacoes-fundamentadas-sindec-2012.csv
df2 = pd.read_csv('/content/drive/MyDrive/Datasets/reclamacoes-fundamentadas-sindec-2013.csv', nrows=3000) #Le o arquivo reclamacoes-fundamentadas-sindec-2013.csv
df3 = pd.read_csv('/content/drive/MyDrive/Datasets/reclamacoes-fundamentadas-sindec-2014.csv', nrows=3000) #Le o arquivo reclamacoes-fundamentadas-sindec-2014.csv
df4 = pd.read_csv('/content/drive/MyDrive/Datasets/reclamacoes-fundamentadas-sindec-2015.csv', nrows=3000) #Le o arquivo reclamacoes-fundamentadas-sindec-2015.csv
df5 = pd.read_csv('/content/drive/MyDrive/Datasets/reclamacoes-fundamentadas-sindec-2016.csv', nrows=3000) #Le o arquivo reclamacoes-fundamentadas-sindec-2016.csv

# %%
df1.shape, df2.shape, df3.shape, df4.shape, df5.shape #Mostra quantidade de colunas e registros
# Out:
# ((1000, 23), (3000, 23), (3000, 23), (3000, 23), (3000, 23))

# %%
df1.sample(2) #Pega dois elementos do primeiro dataset
# Out:
#      AnoCalendario         DataArquivamento             DataAbertura  \
# 84            2012  2012-01-05 12:34:28.000  2010-06-17 09:38:57.000
# 472           2012  2012-02-13 16:35:38.000  2011-04-26 10:10:13.000
#
#      CodigoRegiao   Regiao  UF strRazaoSocial  \
# 84              1    Norte  AP   P. L. CAMPOS
# 472             3  Sudeste  MG     VIA VAREJO
#
#                         strNomeFantasia  Tipo    NumeroCNPJ  ...  \
# 84   TOQUE DE CARINHO/TOQUE INTELIGENTE     1  7.967054e+12  ...
# 472                          PONTO FRIO     1  3.304126e+13  ...
#
#      CNAEPrincipal                                DescCNAEPrincipal Atendida  \
# 84       4789002.0  COMÉRCIO VAREJISTA DE PLANTAS E FLORES NATURAIS        N
# 472      4713001.0              LOJAS DE DEPARTAMENTOS OU MAGAZINES        N
#
#      CodigoAssunto                         DescricaoAssunto CodigoProblema  \
# 84              73  Estabelecimento / Loja - Compra a Prazo             28
# ...

# %%
df2.sample(2) #Pega dois elementos do segundo dataset
# Out:
#      AnoCalendario         DataArquivamento             DataAbertura  \
# 25            2013  2013-04-01 12:38:02.000  2012-12-13 10:01:08.000
# 495           2013  2013-09-27 16:37:25.000  2013-01-30 12:49:09.000
#
#      CodigoRegiao    Regiao  UF                 strRazaoSocial  \
# 25              2  Nordeste  RN                     ALEX RODAS
# 495             2  Nordeste  BA  HIPERCARD BANCO MULTIPLO S.A.
#
#               strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 25                 ALEX RODAS     1           NaN  ...            NaN
# 495  HIPERCARD BANCO MULTIPLO     1  3.012230e+12  ...      6422100.0
#
#                             DescCNAEPrincipal Atendida  CodigoAssunto  \
# 25                                        NaN        S             89
# 495  BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL        S             54
#
#                                       DescricaoAssunto CodigoProblema  \
# ...

# %%
df3.sample(2) #Pega dois elementos do terceiro dataset
# Out:
#       AnoCalendario         DataArquivamento             DataAbertura  \
# 2615           2014  2014-01-03 17:20:41.000  2013-05-02 11:14:56.000
# 263            2014  2014-02-26 12:08:11.000  2013-02-18 12:57:53.000
#
#       CodigoRegiao    Regiao  UF                    strRazaoSocial  \
# 2615             2  Nordeste  BA           TELEMAR NORTE LESTE S/A
# 263              1     Norte  AC  LOSANGO PROMOCOES DE VENDAS LTDA
#
#      strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 2615    TELEMAR - OI     1  3.300012e+13  ...      6110801.0
# 263          LOSANGO     1  5.281313e+12  ...      7490104.0
#
#                                       DescCNAEPrincipal Atendida  \
# 2615         SERVIÇOS DE TELEFONIA FIXA COMUTADA - STFC        N
# 263   ATIVIDADES DE INTERMEDIAÇÃO E AGENCIAMENTO DE ...        N
#
#       CodigoAssunto                                 DescricaoAssunto  \
# 2615            279  Informática (Ex.:Provedor de Acesso a Internet)
# ...

# %%
df4.sample(2) #Pega dois elementos do quarto dataset
# Out:
#       AnoCalendario         DataArquivamento             DataAbertura  \
# 660            2015  2015-12-14 09:54:10.000  2015-10-30 11:38:12.000
# 1193           2015  2015-01-30 15:00:52.000  2014-10-02 10:43:22.000
#
#       CodigoRegiao   Regiao  UF                   strRazaoSocial  \
# 660              3  Sudeste  SP              MAGAZINE LUIZA S.A.
# 1193             3  Sudeste  ES  ROYAL E SUNALLIANCE SEGUROS S/A
#
#                   strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 660   MAGAZINE LUIZA - SAC/PROCON     1  4.796095e+13  ...      4713001.0
# 1193                ROYAL SEGUROS     1  3.306570e+13  ...      6512000.0
#
#                         DescCNAEPrincipal Atendida  CodigoAssunto  \
# 660   LOJAS DE DEPARTAMENTOS OU MAGAZINES        N            134
# 1193                     SEGUROS NÃO-VIDA        S            282
#
#                                        DescricaoAssunto CodigoProblema  \
# ...

# %%
df5.sample(2) #Pega dois elementos do quinto dataset
# Out:
#       AnoCalendario         DataArquivamento             DataAbertura  \
# 2704           2016  2016-01-11 16:21:45.000  2015-12-03 10:52:10.000
# 2234           2016  2016-09-15 14:25:44.000  2016-07-25 11:44:48.000
#
#       CodigoRegiao    Regiao  UF                              strRazaoSocial  \
# 2704             2  Nordeste  CE     BOMPREÇO SUPERMERCADOS DO NORDESTE LTDA
# 2234             3   Sudeste  SP  ESSENCIAL COM ELETRÓNICOS MÓVEIS ELETRODOM
#
#                                     strNomeFantasia  Tipo    NumeroCNPJ  ...  \
# 2704                                 HIPER BOMPREÇO     1  1.300451e+13  ...
# 2234  ESSENCIAL ELETRO / WWW.ESSENCIALELETRO.COM.BR     1  2.380889e+13  ...
#
#       CNAEPrincipal                                  DescCNAEPrincipal  \
# 2704      4711301.0  COMÉRCIO VAREJISTA DE MERCADORIAS EM GERAL, CO...
# 2234            NaN                                                NaN
#
# ...

# %%
frames = [df1, df2, df3, df4, df5] #Nome dos conjuntos de dados

# %%
df_full = pd.concat(frames) #Concatena os datasets
df_full.shape
# Out:
# (13000, 23)

# %%
df_full.sample(3) #Datasets concatenados
# Out:
#       AnoCalendario         DataArquivamento             DataAbertura  \
# 910            2013  2013-08-01 16:46:57.000  2013-06-18 16:15:04.000
# 308            2013  2013-07-23 09:31:07.000  2013-06-21 10:44:11.000
# 2980           2014  2014-10-03 10:58:35.000  2014-02-06 14:44:58.000
#
#       CodigoRegiao    Regiao  UF                   strRazaoSocial  \
# 910              4       Sul  SC  VIDEOSERVICE ELETRONICA LTDA ME
# 308              3   Sudeste  ES  LG ELECTRONICS DA AMAZÔNIA LTDA
# 2980             2  Nordeste  BA                       CLARO S.A.
#
#                strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 910   VIDEO SERVICE ELETRONICA     1  2.163819e+12  ...      9521500.0
# 308             LG ELECTRONICS     1  8.014500e+11  ...      2640000.0
# 2980                     CLARO     1  4.043254e+13  ...      6120501.0
#
#                                       DescCNAEPrincipal Atendida  \
# ...
